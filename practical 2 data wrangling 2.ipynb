# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r'C:\Users\ganes\Desktop\dsbda practicals\parnavv\STUDENT_PERFORMANCE.csv')

# %%
df
# Out:
#     gender maths_score  reading_score  writing_score  placement_score  \
# 0   Female          63           92.0           69.0             83.0
# 1   Female          62           92.0           72.0             81.0
# 2   Female          84           84.0           67.0             92.0
# 3     Male          68           84.0           77.0             83.0
# 4   Female          74           84.0           69.0              NaN
# 5     Male          69           77.0           69.0             76.0
# 6   Female          61           81.0           72.0             84.0
# 7     Male          62           78.0           65.0             95.0
# 8   Female          62           90.0            NaN             76.0
# 9     Male          76           90.0           70.0             84.0
# 10  Female          65           85.0           62.0             94.0
# 11  Female          71           78.0           80.0             76.0
# ...

# %%
df.head()
# Out:
#    gender maths_score  reading_score  writing_score  placement_score  \
# 0  Female          63           92.0           69.0             83.0
# 1  Female          62           92.0           72.0             81.0
# 2  Female          84           84.0           67.0             92.0
# 3    Male          68           84.0           77.0             83.0
# 4  Female          74           84.0           69.0              NaN
#
#    club_join_date  placement_offer_count
# 0          2021.0                    2.0
# 1          2018.0                    2.0
# 2          2021.0                    3.0
# 3          2019.0                    2.0
# 4          2021.0                    2.0

# %%
df.tail()
# Out:
#     gender maths_score  reading_score  writing_score  placement_score  \
# 24  Female         NaN           88.0           71.0             97.0
# 25    Male          69           79.0           80.0             99.0
# 26     NaN         NaN            NaN            NaN              NaN
# 27    Male          63           75.0           72.0             84.0
# 28    Male         Nan           80.0           71.0             83.0
#
#     club_join_date  placement_offer_count
# 24          2020.0                    3.0
# 25          2019.0                    3.0
# 26             NaN                    NaN
# 27          2019.0                    NaN
# 28          2021.0                    2.0

# %%
df.describe()
# Out:
#        reading_score  writing_score  placement_score  club_join_date  \
# count      26.000000      27.000000        26.000000       28.000000
# mean       83.884615      69.740741        85.576923     2019.428571
# std         6.015493       5.654084         7.150793        1.230133
# min        75.000000      61.000000        76.000000     2018.000000
# 25%        79.250000      64.500000        81.500000     2018.000000
# 50%        84.000000      70.000000        84.000000     2019.000000
# 75%        89.500000      73.000000        92.000000     2021.000000
# max        95.000000      80.000000        99.000000     2021.000000
#
#        placement_offer_count
# count              24.000000
# mean                2.375000
# std                 0.494535
# min                 2.000000
# 25%                 2.000000
# 50%                 2.000000
# 75%                 3.000000
# max                 3.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   gender                 28 non-null     object
#  1   maths_score            27 non-null     object
#  2   reading_score          26 non-null     float64
#  3   writing_score          27 non-null     float64
#  4   placement_score        26 non-null     float64
#  5   club_join_date         28 non-null     float64
#  6   placement_offer_count  24 non-null     float64
# dtypes: float64(5), object(2)
# memory usage: 1.7+ KB

# %%
df.isnull()
# Out:
#     gender  maths_score  reading_score  writing_score  placement_score  \
# 0    False        False          False          False            False
# 1    False        False          False          False            False
# 2    False        False          False          False            False
# 3    False        False          False          False            False
# 4    False        False          False          False             True
# 5    False        False          False          False            False
# 6    False        False          False          False            False
# 7    False        False          False          False            False
# 8    False        False          False           True            False
# 9    False        False          False          False            False
# 10   False        False          False          False            False
# 11   False        False          False          False            False
# ...

# %%
df.isnull().sum()
# Out:
# gender                   1
# maths_score              2
# reading_score            3
# writing_score            2
# placement_score          3
# club_join_date           1
# placement_offer_count    5
# dtype: int64

# %%
col=['reading_score', 'writing_score','placement_score','club_join_date']
df.boxplot(col)
# Out:
# <AxesSubplot:>

# %%
fig, ax = plt.subplots(figsize=(18, 10))
ax.scatter(df['placement_score'], df['placement_offer_count'])
plt.show()

# %%
ndf = df
print("Before filling null values")
ndf.head(40)
# Out:
# Before filling null values
#     gender maths_score  reading_score  writing_score  placement_score  \
# 0   Female          63           92.0           69.0             83.0
# 1   Female          62           92.0           72.0             81.0
# 2   Female          84           84.0           67.0             92.0
# 3     Male          68           84.0           77.0             83.0
# 4   Female          74           84.0           69.0              NaN
# 5     Male          69           77.0           69.0             76.0
# 6   Female          61           81.0           72.0             84.0
# 7     Male          62           78.0           65.0             95.0
# 8   Female          62           90.0            NaN             76.0
# 9     Male          76           90.0           70.0             84.0
# 10  Female          65           85.0           62.0             94.0
# 11  Female          71           78.0           80.0             76.0
# ...

# %%
ndf = ndf.fillna(0)
print("Before filling null values")
ndf.head(40)
# Out:
# Before filling null values
#     gender maths_score  reading_score  writing_score  placement_score  \
# 0   Female          63           92.0           69.0             83.0
# 1   Female          62           92.0           72.0             81.0
# 2   Female          84           84.0           67.0             92.0
# 3     Male          68           84.0           77.0             83.0
# 4   Female          74           84.0           69.0              0.0
# 5     Male          69           77.0           69.0             76.0
# 6   Female          61           81.0           72.0             84.0
# 7     Male          62           78.0           65.0             95.0
# 8   Female          62           90.0            0.0             76.0
# 9     Male          76           90.0           70.0             84.0
# 10  Female          65           85.0           62.0             94.0
# 11  Female          71           78.0           80.0             76.0
# ...

# %%
sample_outliers = [0, 1, 5, 7, 8]
ndf = df
print("Before Deleting")
ndf.head(40)
# Out:
# Before Deleting
#     gender maths_score  reading_score  writing_score  placement_score  \
# 0   Female          63           92.0           69.0             83.0
# 1   Female          62           92.0           72.0             81.0
# 2   Female          84           84.0           67.0             92.0
# 3     Male          68           84.0           77.0             83.0
# 4   Female          74           84.0           69.0              NaN
# 5     Male          69           77.0           69.0             76.0
# 6   Female          61           81.0           72.0             84.0
# 7     Male          62           78.0           65.0             95.0
# 8   Female          62           90.0            NaN             76.0
# 9     Male          76           90.0           70.0             84.0
# 10  Female          65           85.0           62.0             94.0
# 11  Female          71           78.0           80.0             76.0
# ...

# %%
for i in sample_outliers:
    ndf = ndf.drop(i)

print("After Deleting")
ndf.head(40)
# Out:
# After Deleting
#     gender maths_score  reading_score  writing_score  placement_score  \
# 2   Female          84           84.0           67.0             92.0
# 3     Male          68           84.0           77.0             83.0
# 4   Female          74           84.0           69.0              NaN
# 6   Female          61           81.0           72.0             84.0
# 9     Male          76           90.0           70.0             84.0
# 10  Female          65           85.0           62.0             94.0
# 11  Female          71           78.0           80.0             76.0
# 12  Female          75           87.0           61.0             83.0
# 13  Female          62           76.0           74.0             77.0
# 14    Male          66           92.0           64.0             86.0
# 15  Female          78            NaN           74.0             84.0
# 16    Male          60           84.0           64.0             78.0
# ...

# %%
ndf = df
ndf.dropna()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-ddbb230b0cb5> in <module>
# ----> 1 ndf = df
#       2 ndf.dropna()
#
# NameError: name 'df' is not defined

# %%
ndf.fillna()
